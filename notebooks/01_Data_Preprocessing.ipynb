# %% [markdown]
# # 📦 Notebook 01: Data Preprocessing
# ## Network Intrusion Detection System — NSL-KDD
#
# **Module:** Foundation
# **Objective:** Load, clean, encode, and save the NSL-KDD dataset
#
# ### Steps:
# 1. Load raw data
# 2. Create binary, multiclass, and severity labels
# 3. One-hot encode categorical features
# 4. Scale numerical features
# 5. Save all processed data

# %%
# ─── Imports ────────────────────────────────────────────────────
import sys
import os
import warnings
warnings.filterwarnings('ignore')

# Add project root to path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, PROJECT_ROOT)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.data_preprocessing import run_full_pipeline
from src.utils import print_header

print("✅ All imports successful")
print(f"📁 Project root: {PROJECT_ROOT}")
# Out:
# ✅ All imports successful
# 📁 Project root: D:\WebDev\Network_Intrusion_Detection

# %%
# ─── Define Paths ───────────────────────────────────────────────
TRAIN_PATH = os.path.join(PROJECT_ROOT, 'data', 'raw', 'KDDTrain+.txt')
TEST_PATH = os.path.join(PROJECT_ROOT, 'data', 'raw', 'KDDTest+.txt')
OUTPUT_DIR = PROJECT_ROOT

# Check if files exist
print(f"Train file exists: {os.path.exists(TRAIN_PATH)}")
print(f"Test file exists:  {os.path.exists(TEST_PATH)}")

if not os.path.exists(TRAIN_PATH):
    print("\n⚠️  Dataset not found!")
    print("Download from: https://www.kaggle.com/datasets/hassan06/nslkdd")
    print("Place KDDTrain+.txt and KDDTest+.txt in data/raw/")
# Out:
# Train file exists: True
# Test file exists:  True

# %%
# ─── Run Full Pipeline ─────────────────────────────────────────
data = run_full_pipeline(TRAIN_PATH, TEST_PATH, OUTPUT_DIR)
# Out:
# ============================================================
#   NSL-KDD PREPROCESSING PIPELINE
# ============================================================
#
# ============================================================
#   Loading NSL-KDD Dataset
# ============================================================
#   Training set: (125973, 42)
#   Testing set:  (22544, 42)
#   Features:     41
#   Unique labels: 23
#
# --- Creating Labels ---
#   Binary distribution:
#     Normal (0): 67343
#     Attack (1): 58630
#
#   Multiclass distribution:
# attack_category
# normal    67343
# dos       45927
# probe     11656
# r2l         995
# u2r          52
#
# --- Creating Labels ---
#   Binary distribution:
#     Normal (0): 9711
#     Attack (1): 12833
#
#   Multiclass distribution:
# attack_category
# normal    9711
# dos       7460
# r2l       2885
# probe     2421
# u2r         67
#
# ============================================================
#   Encoding & Scaling
# ============================================================
#   Fitting preprocessor on training data...
#   Features before encoding: 41
#   Features after encoding:  122
#     Numerical: 38
#     One-hot:   84
# 💾 Model saved: D:\WebDev\Network_Intrusion_Detection\models\encoders\preprocessor.pkl
#
# ============================================================
#   Saving Processed Data
# ============================================================
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\X_train.npy | Shape: (125973, 122)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\X_test.npy | Shape: (22544, 122)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\y_train_binary.npy | Shape: (125973,)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\y_test_binary.npy | Shape: (22544,)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\y_train_multi.npy | Shape: (125973,)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\y_test_multi.npy | Shape: (22544,)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\y_train_severity.npy | Shape: (125973,)
# 💾 Array saved: D:\WebDev\Network_Intrusion_Detection\data\processed\y_test_severity.npy | Shape: (22544,)
# 💾 Model saved: D:\WebDev\Network_Intrusion_Detection\models\encoders\label_encoder_multi.pkl
# ============================================================
#   PIPELINE COMPLETE ✅
# ============================================================
#   X_train shape: (125973, 122)
#   X_test shape:  (22544, 122)
#   Binary classes: [0 1]
#   Multi classes:  [0 1 2 3 4] → ['dos', 'normal', 'probe', 'r2l', 'u2r']
#   Severity range: [0.0, 1.0]

# %%
# ─── Verify Saved Data ─────────────────────────────────────────
print_header("Verification")

processed_dir = os.path.join(PROJECT_ROOT, 'data', 'processed')
files = os.listdir(processed_dir)
print(f"\nFiles in data/processed/:")
for f in sorted(files):
    fpath = os.path.join(processed_dir, f)
    size = os.path.getsize(fpath) / 1024
    print(f"  📄 {f:30s} ({size:8.1f} KB)")

print(f"\n✅ Phase 1 Data Pipeline Complete!")
print(f"   Total features after encoding: {data['X_train'].shape[1]}")
print(f"   Training samples: {data['X_train'].shape[0]}")
print(f"   Testing samples:  {data['X_test'].shape[0]}")
# Out:
# ============================================================
#   Verification
# ============================================================
#
# Files in data/processed/:
#   📄 X_test.npy                     ( 21487.4 KB)
#   📄 X_train.npy                    (120068.1 KB)
#   📄 feature_names.npy              (    13.0 KB)
#   📄 test_preprocessed.csv          (  3317.5 KB)
#   📄 train_preprocessed.csv         ( 18444.5 KB)
#   📄 y_test_binary.npy              (   176.2 KB)
#   📄 y_test_multi.npy               (   176.2 KB)
#   📄 y_test_severity.npy            (   176.2 KB)
#   📄 y_train_binary.npy             (   984.3 KB)
#   📄 y_train_multi.npy              (   984.3 KB)
#   📄 y_train_severity.npy           (   984.3 KB)
#
# ✅ Phase 1 Data Pipeline Complete!
#    Total features after encoding: 122
#    Training samples: 125973
#    Testing samples:  22544
